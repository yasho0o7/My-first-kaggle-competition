# %%
import pandas as pd
import numpy as np

# %%
train_data = pd.read_csv(r"C:\Users\yasho\OneDrive\Documents\Machine Learning\Kaggle\Housing Price Prediction\train.csv")

#To remove NaN, infinity or a value too large for dtype('float64')
#train_data['LotFrontage'].fillna(train_data['LotFrontage'].mean(), inplace = True)
#train_data['PoolQC'] = train_data['PoolQC'].fillna(0)
#train_data['Fence'] = train_data['Fence'].fillna(0)
#train_data['MiscFeature'] = train_data['MiscFeature'].fillna(0)
#train_data.fillna(0)
#train_data.isnull().sum()
train_data.replace([np.inf, -np.inf], np.nan)
trainee=train_data.fillna(0)

# %%
train_data.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 81, dtype: object

# %%
trainee.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
trainee.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave     0      Reg
# 1   2          20       RL         80.0     9600   Pave     0      Reg
# 2   3          60       RL         68.0    11250   Pave     0      IR1
# 3   4          70       RL         60.0     9550   Pave     0      IR1
# 4   5          60       RL         84.0    14260   Pave     0      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0      0     0           0       0      2
# 1         Lvl    AllPub  ...        0      0     0           0       0      5
# 2         Lvl    AllPub  ...        0      0     0           0       0      9
# 3         Lvl    AllPub  ...        0      0     0           0       0      2
# 4         Lvl    AllPub  ...        0      0     0           0       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
trainee.tail(5)
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave     0      Reg
# 1456  1457          20       RL         85.0    13175   Pave     0      Reg
# 1457  1458          70       RL         66.0     9042   Pave     0      Reg
# 1458  1459          20       RL         68.0     9717   Pave     0      Reg
# 1459  1460          20       RL         75.0     9937   Pave     0      Reg
#
#      LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 1455         Lvl    AllPub  ...        0      0      0           0       0
# 1456         Lvl    AllPub  ...        0      0  MnPrv           0       0
# 1457         Lvl    AllPub  ...        0      0  GdPrv        Shed    2500
# 1458         Lvl    AllPub  ...        0      0      0           0       0
# 1459         Lvl    AllPub  ...        0      0      0           0       0
#
#      MoSold YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
train_data['SalePrice']
# Out:
# 0       208500
# 1       181500
# 2       223500
# 3       140000
# 4       250000
#          ...
# 1455    175000
# 1456    210000
# 1457    266500
# 1458    142125
# 1459    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
y = trainee.SalePrice
features = ['LotArea','LotShape','Utilities','Neighborhood','HouseStyle','OverallQual','OverallCond','YearBuilt','YearRemodAdd','Foundation','1stFlrSF', '2ndFlrSF','FullBath','HalfBath','TotRmsAbvGrd']
X = trainee[features]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(rc={'figure.figsize':(16.7,13.27)})
#sns.displot(x="Neighborhood",y="SalePrice", hue="Neighborhood", data=train_data);
#plt.show()

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
trainee['MSZoning'] = le.fit_transform(trainee['MSZoning'].astype(str))
trainee['Street'] = le.fit_transform(trainee['Street'].astype(str))
trainee['Alley'] = le.fit_transform(trainee['Alley'].astype(str))
trainee['LotShape'] = le.fit_transform(trainee['LotShape'].astype(str))
trainee['LandContour'] = le.fit_transform(trainee['LandContour'].astype(str))
trainee['Utilities'] = le.fit_transform(trainee['Utilities'].astype(str))
trainee['LotConfig'] = le.fit_transform(trainee['LotConfig'].astype(str))
trainee['LandSlope'] = le.fit_transform(trainee['LandSlope'].astype(str))
trainee['LotConfig'] = le.fit_transform(trainee['LotConfig'].astype(str))
trainee['Neighborhood'] = le.fit_transform(trainee['Neighborhood'].astype(str))
trainee['Condition1'] = le.fit_transform(trainee['Condition1'].astype(str))
trainee['Condition2'] = le.fit_transform(trainee['Condition2'].astype(str))
trainee['BldgType'] = le.fit_transform(trainee['BldgType'].astype(str))
trainee['HouseStyle'] = le.fit_transform(trainee['HouseStyle'].astype(str))
trainee['RoofStyle'] = le.fit_transform(trainee['RoofStyle'].astype(str))
trainee['RoofMatl'] = le.fit_transform(trainee['RoofMatl'].astype(str))
trainee['Exterior1st'] = le.fit_transform(trainee['Exterior1st'].astype(str))
trainee['Exterior2nd'] = le.fit_transform(trainee['Exterior2nd'].astype(str))
trainee['MasVnrType'] = le.fit_transform(trainee['MasVnrType'].astype(str))
trainee['ExterQual'] = le.fit_transform(trainee['ExterQual'].astype(str))
trainee['MasVnrArea'] = le.fit_transform(trainee['MasVnrArea'].astype(str))
trainee['ExterCond'] = le.fit_transform(trainee['ExterCond'].astype(str))
trainee['Foundation'] = le.fit_transform(trainee['Foundation'].astype(str))
trainee['BsmtQual'] = le.fit_transform(trainee['BsmtQual'].astype(str))
trainee['BsmtCond'] = le.fit_transform(trainee['BsmtCond'].astype(str))
trainee['BsmtExposure'] = le.fit_transform(trainee['BsmtExposure'].astype(str))
trainee['BsmtFinType1'] = le.fit_transform(trainee['BsmtFinType1'].astype(str))
trainee['BsmtFinType2'] = le.fit_transform(trainee['BsmtFinType2'].astype(str))
trainee['Heating'] = le.fit_transform(trainee['Heating'].astype(str))
trainee['HeatingQC'] = le.fit_transform(trainee['HeatingQC'].astype(str))
trainee['CentralAir'] = le.fit_transform(trainee['CentralAir'].astype(str))
trainee['Electrical'] = le.fit_transform(trainee['Electrical'].astype(str))
trainee['KitchenQual'] = le.fit_transform(trainee['KitchenQual'].astype(str))
trainee['Functional'] = le.fit_transform(trainee['Functional'].astype(str))
trainee['FireplaceQu'] = le.fit_transform(trainee['FireplaceQu'].astype(str))
trainee['GarageType'] = le.fit_transform(trainee['GarageType'].astype(str))
trainee['GarageFinish'] = le.fit_transform(trainee['GarageFinish'].astype(str))
trainee['GarageQual'] = le.fit_transform(trainee['GarageQual'].astype(str))
trainee['GarageCond'] = le.fit_transform(trainee['GarageCond'].astype(str))
trainee['PavedDrive'] = le.fit_transform(trainee['PavedDrive'].astype(str))
trainee['PoolQC'] = le.fit_transform(trainee['PoolQC'].astype(str))
trainee['Fence'] = le.fit_transform(trainee['Fence'].astype(str))
trainee['MiscFeature'] = le.fit_transform(trainee['MiscFeature'].astype(str))
trainee['SaleType'] = le.fit_transform(trainee['SaleType'].astype(str))
trainee['SaleCondition'] = le.fit_transform(trainee['SaleCondition'].astype(str))

# %%
trainee.head(2)
# Out:
#    Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0   1          60         3         65.0     8450       1      0         3
# 1   2          20         3         80.0     9600       1      0         3
#
#    LandContour  Utilities  ...  PoolArea  PoolQC  Fence  MiscFeature  MiscVal  \
# 0            3          0  ...         0       0      0            0        0
# 1            3          0  ...         0       0      0            0        0
#
#    MoSold  YrSold  SaleType  SaleCondition  SalePrice
# 0       2    2008         8              4     208500
# 1       5    2007         8              4     181500
#
# [2 rows x 81 columns]

# %%
cols = [col for col in train_data.columns if col not in ['Id','SalePrice']]
data = trainee[cols]
target = trainee['SalePrice']

# %%
from sklearn.model_selection import train_test_split
data_train, data_test, target_train, target_test = train_test_split(data, target,test_size = 0.20, random_state=10)

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

gnb = GaussianNB()

pred = gnb.fit(data_train, target_train).predict(data_test)


print("Naive-Bayes accuracy : ",accuracy_score(target_test, pred, normalize = True))
# Out:
# Naive-Bayes accuracy :  0.010273972602739725

# %%
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score

svc_model = LinearSVC(random_state=10)

pred = svc_model.fit(data_train, target_train).predict(data_test)

print("LinearSVC accuracy : ",accuracy_score(target_test, pred, normalize = True))
# Out:
# LinearSVC accuracy :  0.0
# c:\users\yasho\appdata\local\programs\python\python38\lib\site-packages\sklearn\svm\_base.py:976: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

neigh = KNeighborsClassifier(n_neighbors=3)

neigh.fit(data_train, target_train)

pred = neigh.predict(data_test)

print ("KNeighbors accuracy score : ",accuracy_score(target_test, pred))
# Out:
# KNeighbors accuracy score :  0.02054794520547945
